# %%
import pandas as pd
from astropy.io import fits
import math
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
import skimage.draw
from photutils.aperture import aperture_photometry
from astropy.stats import sigma_clip
import psycopg2
import copy
from photutils import CircularAnnulus, EllipticalAperture
import math
from pathlib import Path
from tqdm import tqdm
import nayo
import sqlalchemy as sqla

conn = nayo.connect_db()
# Out:
# /tmp/ipykernel_64/3381239784.py:13: DeprecationWarning: `photutils.CircularAnnulus` is a deprecated alias for `photutils.aperture.CircularAnnulus` and will be removed in the future. Instead, please use `from photutils.aperture import CircularAnnulus` to silence this warning.
#   from photutils import CircularAnnulus, EllipticalAperture
# /tmp/ipykernel_64/3381239784.py:13: DeprecationWarning: `photutils.EllipticalAperture` is a deprecated alias for `photutils.aperture.EllipticalAperture` and will be removed in the future. Instead, please use `from photutils.aperture import EllipticalAperture` to silence this warning.
#   from photutils import CircularAnnulus, EllipticalAperture

# %%
def background_annulus(data, mask, aperture_x, aperture_y, r_in=30, r_out=45):
    """Measure background in an annulus."""
    
    masked_data = np.ma.array(data=data, mask=mask != 0)
    masked_data = masked_data.filled(fill_value=0)

    center = (aperture_x, aperture_y)
    annulus_apertures = CircularAnnulus(center, r_in=r_in, r_out=r_out)
    masks = annulus_apertures.to_mask(method='center')

    cutout_data = masks.cutout(masked_data)

    clip_annulus_array = sigma_clip(cutout_data[cutout_data != 0], sigma=3, maxiters=2)

    S = pd.Series()
    S['annulus_mean'] = np.ma.mean(clip_annulus_array)
    S['annulus_median'] = np.ma.median(clip_annulus_array)
    S['annulus_std'] = np.ma.std(clip_annulus_array)
    S['annulus_samples'] = np.ma.count(clip_annulus_array)

    return S

def flux_elliptical(image, mask, aperture_x, aperture_y, aperture_theta, aperture_a, aperture_b):
    """Measure the flux withing an elliptical aperture."""
    
    PIXEL_SCALE = 0.263
    theta = -aperture_theta * np.pi / 180.
    a = aperture_a / PIXEL_SCALE
    b = aperture_b / PIXEL_SCALE

    center = (aperture_x, aperture_y)
    source_aperture = EllipticalAperture(center, a, b, theta)

    xmask = mask != 0
    raw_flux = aperture_photometry(image, source_aperture, mask=xmask)
   
    S = pd.Series()
    S['raw_flux'] = float(raw_flux['aperture_sum'][0])
    S['area'] = source_aperture.area
    
    return S

def cal_calerror(sig_src,sig_zp,zp,f_src):
    sig_cal = np.sqrt(sig_src**2 * sig_zp**2 + sig_src**2 * zp**2 + sig_zp**2 * f_src**2)
    return sig_cal

def cal_fcal(f_src,zp):
    f_cal = f_src * zp
    return f_cal

def creat_stamps(image, sources):
    y = math.floor(sources['aperture_x'].values[0])
    x = math.floor(sources['aperture_y'].values[0])
    #y = math.floor(sources['aperture_x'])
    #x = math.floor(sources['aperture_y'])
    x_start = max((x - cutout_size), 0)
    x_end = min((x + cutout_size), image.shape[0])
    y_start = max((y - cutout_size), 0)
    y_end = min((y + cutout_size), image.shape[1])

    stamps = image[x_start:x_end, y_start:y_end]
    return stamps

def photometry_oneimage(image, mask, aperture_x, aperture_y, aperture_theta, aperture_a, aperture_b):
    
    S1 = background_annulus(image, mask, aperture_x, aperture_y)
    S2 = flux_elliptical(image, mask, aperture_x, aperture_y, aperture_theta, aperture_a, aperture_b)

    flux_obs = S2['raw_flux'] - S2['area'] * S1['annulus_median']
    return flux_obs, S1['annulus_std']

def generate_mask(size_data, image):

    num_sample = int(size_data[0] * size_data[1] * (1 - ratio))
    mask = np.ones(size_data)
    output = image

    for ich in range(size_data[2]):
        idy_msk = np.random.randint(0, size_data[0], num_sample)
        idx_msk = np.random.randint(0, size_data[1], num_sample)

        idy_neigh = np.random.randint(-size_window[0] // 2 + size_window[0] % 2, size_window[0] // 2 + size_window[0] % 2, num_sample)
        idx_neigh = np.random.randint(-size_window[1] // 2 + size_window[1] % 2, size_window[1] // 2 + size_window[1] % 2, num_sample)

        idy_msk_neigh = idy_msk + idy_neigh
        idx_msk_neigh = idx_msk + idx_neigh

        idy_msk_neigh = idy_msk_neigh + (idy_msk_neigh < 0) * size_data[0] - (idy_msk_neigh >= size_data[0]) * size_data[0]
        idx_msk_neigh = idx_msk_neigh + (idx_msk_neigh < 0) * size_data[1] - (idx_msk_neigh >= size_data[1]) * size_data[1]

        id_msk = (idy_msk, idx_msk, ich)
        id_msk_neigh = (idy_msk_neigh, idx_msk_neigh, ich)

        output[id_msk] = image[id_msk_neigh]
        mask[id_msk] = 0.0

    return output, mask

# %%
#write the function to calculate the flux by myself

def background_annulus_jiefeng(data, mask, aperture_x, aperture_y, r_in=30, r_out=45):
    
    masked_data = np.ma.array(data=data, mask=mask != 0)
    masked_data = masked_data.filled(fill_value=0)

    center = (aperture_x, aperture_y)
    annulus_apertures = CircularAnnulus(center, r_in=r_in, r_out=r_out)
    masks = annulus_apertures.to_mask(method='center')
    print(masked_data.shape)
    cutout_data = masks.cutout(masked_data)

    clip_annulus_array = sigma_clip(cutout_data[cutout_data != 0], sigma=3, maxiters=2)

    #background_annulus = np.ma.mean(clip_annulus_array)
    #we use median here, in the dataset they use mdian
    background_annulus = np.ma.median(clip_annulus_array)
    return background_annulus

def flux_elliptical_jiefeng(image, mask, aperture_x, aperture_y, aperture_theta, aperture_a, aperture_b):

    image_shape = (cutout_size*2,cutout_size*2)
    PIXEL_SCALE = 0.263
    theta = -aperture_theta * np.pi / 180.
    a = aperture_a / PIXEL_SCALE
    b = aperture_b / PIXEL_SCALE

    center = (aperture_x, aperture_y)
    source_aperture = EllipticalAperture(center, a, b, theta)
    mask_object = source_aperture.to_mask(method='exact')
    mask_image_photutils_fractional = mask_object.to_image(shape=image_shape)
    
    xmask = mask != 0
    image_good = image * (1 - xmask)
    
    raw_flux = np.sum(image_good * mask_image_photutils_fractional)#calculate by myself

    background = background_annulus_jiefeng(image, mask, aperture_x, aperture_y)
    
    gal_flux = raw_flux - source_aperture.area * background
    return gal_flux

# %%
#write the function to calculate the flux by myself

def background_annulus_jiefeng(data, mask, aperture_x, aperture_y, r_in=30, r_out=45):
    
    masked_data = np.ma.array(data=data, mask=mask != 0)
    masked_data = masked_data.filled(fill_value=0)

    center = (aperture_x, aperture_y)
    annulus_apertures = CircularAnnulus(center, r_in=r_in, r_out=r_out)
    masks = annulus_apertures.to_mask(method='center')
    print(masked_data.shape)
    cutout_data = masks.cutout(masked_data)

    clip_annulus_array = sigma_clip(cutout_data[cutout_data != 0], sigma=3, maxiters=2)

    #background_annulus = np.ma.mean(clip_annulus_array)
    #we use median here, in the dataset they use mdian
    background_annulus = np.ma.median(clip_annulus_array)
    return background_annulus

def flux_elliptical_jiefeng(image, mask, aperture_x, aperture_y, aperture_theta, aperture_a, aperture_b):

    image_shape = (cutout_size*2,cutout_size*2)
    PIXEL_SCALE = 0.263
    theta = -aperture_theta * np.pi / 180.
    a = aperture_a / PIXEL_SCALE
    b = aperture_b / PIXEL_SCALE

    center = (aperture_x, aperture_y)
    source_aperture = EllipticalAperture(center, a, b, theta)
    mask_object = source_aperture.to_mask(method='exact')
    mask_image_photutils_fractional = mask_object.to_image(shape=image_shape)
    
    xmask = mask != 0
    image_good = image * (1 - xmask)
    
    raw_flux = np.sum(image_good * mask_image_photutils_fractional)#calculate by myself

    return raw_flux, source_aperture.area

# %%
dsn = 'postgresql://readonly:PAUsc1ence@db.pau.pic.es/dm'
engine = sqla.create_engine(dsn)

sql = """SELECT fa.image_id, fa.ref_id, image.ccd_num, image.filter, cosmos."I_auto",zp.zp, zp.zp_error, fa.flux, fa.flux_error,
mosaic.filename, mosaic.archivepath, fa.aperture_x, fa.aperture_y, fa.aperture_theta, fa.aperture_a, fa.aperture_b
FROM forced_aperture AS fa 
JOIN image ON image_id = image.id 
JOIN mosaic ON image.mosaic_id = mosaic.id 
JOIN image_zp AS zp ON zp.image_id=fa.image_id
JOIN cosmos ON fa.ref_id = cosmos.paudm_id WHERE fa.production_id=821
AND 20<"I_auto" AND "I_auto"<21
AND fa.flag=0 AND zp.phot_method_id = 2"""
#AND 18<"I_auto" AND "I_auto"<19. 20,22

df1 = pd.read_sql(sql, engine)

# %%
df1['archivepath'] = df1['archivepath'].str.replace('NightlyR10', 'NightlyR11')
df1['filename'] = df1['filename'].str.replace('red_paucam.', 'red_NightlyR11.paucam.')
df1['archivepath'] = df1['archivepath'].str.replace('tape', 'disk')
def replace_partial(row):
    return row['filename'].replace('.std.', f'.std.0{row.ccd_num}.')

df1['filename'] = df1.apply(replace_partial, axis=1)
df1['path'] = df1['archivepath'] + '/' + df1['filename']

# %%
df1['flux_ca_error'] = cal_calerror(df1['flux_error'],df1['zp_error'],df1['zp'],df1['flux'])
df1['flux_ca'] = cal_fcal(df1['flux'],df1['zp'])

# %%
filtered_df = df1.loc[(df1['filter'] == 'NB705')]
filtered_df = filtered_df[filtered_df['image_id'] != 3974236]
filtered_df = filtered_df.reset_index(drop=True)

# %%
filtered_df = filtered_df[filtered_df['image_id'] == 3977749]
filtered_df = filtered_df.reset_index(drop=True)

# %%
image_id_elements = filtered_df['image_id'].unique()
element_counts = filtered_df['image_id'].value_counts()
print(image_id_elements.shape)
print(element_counts)
# Out:
# (1,)
# image_id
# 3977749    52
# Name: count, dtype: int64

# %%
#calculate the flux with nayo
import time
start_time = time.perf_counter()

model_dir = Path('/home/eriksen/data/bkgnet/models')
df_image_dict_NB705 = {}

#L = []
for i in tqdm(range(len(image_id_elements))):
    selected_image_id = filtered_df[filtered_df.image_id == 3977749]
    image = fits.getdata(selected_image_id['path'].iloc[0])
    mask = fits.getdata(selected_image_id['path'].iloc[0].replace('.fits', '.mask.fits'))
    fname_img = selected_image_id['filename'].iloc[0]
    
    exp_num = int(fname_img.split('.')[2])
    interv = 'after' if 13 < exp_num else 'before' # Fix this number (13)
    band = selected_image_id['filter'].iloc[0]
    
    flux = nayo.photometry(image, mask, selected_image_id, model_dir, interv, band)
    df_image_dict_NB705[f'image_id_{image_id_elements[i]}'] = flux

end_time = time.perf_counter()
elapsed_time = end_time - start_time
print(f"运行时间: {elapsed_time:.5f} 秒")
# Out:
# 100%|██████████| 1/1 [00:02<00:00,  2.75s/it]
# 运行时间: 2.75501 秒

# %%
addflux_df_image_dict_NB705 = {}

for i in tqdm(range(len(image_id_elements))):
    a = df_image_dict_NB705[list(df_image_dict_NB705.keys())[i]]
    a['flux_obs'] = a['raw_flux'] - a['area'] * a['annulus_median']
    
    b = filtered_df[filtered_df['image_id'] == image_id_elements[i]]
    df_combined = pd.concat([a, b], axis=1)
    addflux_df_image_dict_NB705[f'image_id_{image_id_elements[i]}'] = df_combined
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 252.70it/s]

# %%
filtered_df = pd.concat(addflux_df_image_dict_NB705.values(), ignore_index=True)
filtered_df
# Out:
#     annulus_mean  annulus_median  annulus_std  annulus_samples    raw_flux  \
# 0       1.702658        1.700675     0.177788           8229.0  124.010657
# 1       1.702658        1.700675     0.177788           8229.0  124.010657
# 2       1.757173        1.751017     0.194976           8178.0  187.044295
# 3       1.757173        1.751017     0.194976           8178.0  187.044295
# 4       1.725382        1.724273     0.184387           8242.0  108.545350
# 5       1.725382        1.724273     0.184387           8242.0  108.545350
# 6       1.742739        1.739705     0.180998           8255.0   93.829153
# 7       1.742739        1.739705     0.180998           8255.0   93.829153
# 8       1.776646        1.775522     0.185897           8250.0  134.950136
# 9       1.776646        1.775522     0.185897           8250.0  134.950136
# 10      1.783246        1.780872     0.187061           8227.0   67.029118
# 11      1.783246        1.780872     0.187061           8227.0   67.029118
# 12      1.827958        1.824719     0.193788           8252.0  106.803895
# 13      1.827958        1.824719     0.193788           8252.0  106.803895
# 14      1.819084        1.816540     0.196772           8245.0   73.809385
# 15      1.819084        1.816540     0.196772           8245.0   73.809385
# 16      1.851344        1.851503     0.200438           8229.0   91.280148
# 17      1.851344        1.851503     0.200438           8229.0   91.280148
# 18      1.782157        1.778252     0.187342           8227.0   51.293764
# 19      1.782157        1.778252     0.187342           8227.0   51.293764
# 20      1.797774        1.796530     0.191664           8235.0  143.473565
# 21      1.797774        1.796530     0.191664           8235.0  143.473565
# 22      1.841485        1.841581     0.199669           8219.0  155.889976
# 23      1.841485        1.841581     0.199669           8219.0  155.889976
# 24      1.715329        1.713835     0.178442           8237.0   47.978791
# 25      1.715329        1.713835     0.178442           8237.0   47.978791
# 26      1.710071        1.711259     0.178519           8233.0  194.657726
# 27      1.710071        1.711259     0.178519           8233.0  194.657726
# 28      1.741858        1.738890     0.191023           8197.0   47.592333
# 29      1.741858        1.738890     0.191023           8197.0   47.592333
# 30      1.749414        1.749179     0.181007           8241.0  184.668851
# 31      1.749414        1.749179     0.181007           8241.0  184.668851
# 32      1.759464        1.761463     0.184616           8223.0   63.884176
# 33      1.759464        1.761463     0.184616           8223.0   63.884176
# 34      1.723411        1.721211     0.183207           8260.0  108.204282
# 35      1.723411        1.721211     0.183207           8260.0  108.204282
# 36      1.735936        1.733354     0.180699           8236.0   55.384617
# 37      1.735936        1.733354     0.180699           8236.0   55.384617
# 38      1.785858        1.785806     0.188423           8226.0   69.940313
# 39      1.785858        1.785806     0.188423           8226.0   69.940313
# 40      1.784993        1.782399     0.185573           8220.0  102.609202
# 41      1.784993        1.782399     0.185573           8220.0  102.609202
# 42      1.724179        1.721577     0.181884           8222.0   48.616497
# 43      1.724179        1.721577     0.181884           8222.0   48.616497
# 44      1.740397        1.739459     0.185170           8202.0   88.966896
# 45      1.740397        1.739459     0.185170           8202.0   88.966896
# 46      1.762952        1.762048     0.184230           8245.0   94.587482
# 47      1.762952        1.762048     0.184230           8245.0   94.587482
# 48      1.827434        1.825101     0.193809           8253.0  104.537676
# 49      1.827434        1.825101     0.193809           8253.0  104.537676
# 50      1.892704        1.892744     0.211858           8262.0  117.002703
# 51      1.892704        1.892744     0.211858           8262.0  117.002703
#
#          area   flux_obs  image_id  ref_id  ccd_num  ...  \
# 0   58.220573  24.996370   3977749      30        7  ...
# 1   58.220573  24.996370   3977749      30        7  ...
# 2   92.026114  25.904975   3977749     249        7  ...
# 3   92.026114  25.904975   3977749     249        7  ...
# 4   51.628878  19.523079   3977749      59        7  ...
# 5   51.628878  19.523079   3977749      59        7  ...
# 6   47.366286  11.425807   3977749     299        7  ...
# 7   47.366286  11.425807   3977749     299        7  ...
# 8   63.646150  21.944996   3977749     243        7  ...
# 9   63.646150  21.944996   3977749     243        7  ...
# 10  32.043987   9.962890   3977749     111        7  ...
# 11  32.043987   9.962890   3977749     111        7  ...
# 12  50.617684  14.440854   3977749      45        7  ...
# 13  50.617684  14.440854   3977749      45        7  ...
# 14  33.388734  13.157413   3977749     376        7  ...
# 15  33.388734  13.157413   3977749     376        7  ...
# 16  38.441184  20.106171   3977749     531        7  ...
# 17  38.441184  20.106171   3977749     531        7  ...
# 18  20.407535  15.004017   3977749     110        7  ...
# 19  20.407535  15.004017   3977749     110        7  ...
# 20  73.219897  11.931787   3977749     197        7  ...
# 21  73.219897  11.931787   3977749     197        7  ...
# 22  71.679092  23.887089   3977749     358        7  ...
# 23  71.679092  23.887089   3977749     358        7  ...
# 24  20.407535  13.003641   3977749      34        7  ...
# 25  20.407535  13.003641   3977749      34        7  ...
# 26  95.542145  31.160324   3977749       2        7  ...
# 27  95.542145  31.160324   3977749       2        7  ...
# 28  20.407535  12.105881   3977749     211        7  ...
# 29  20.407535  12.105881   3977749     211        7  ...
# 30  93.412611  21.273483   3977749     268        7  ...
# 31  93.412611  21.273483   3977749     268        7  ...
# 32  20.407535  27.937052   3977749     234        7  ...
# 33  20.407535  27.937052   3977749     234        7  ...
# 34  55.051475  13.449093   3977749     315        7  ...
# 35  55.051475  13.449093   3977749     315        7  ...
# 36  23.286493  15.020890   3977749     310        7  ...
# 37  23.286493  15.020890   3977749     310        7  ...
# 38  20.407535  33.496418   3977749     245        7  ...
# 39  20.407535  33.496418   3977749     245        7  ...
# 40  50.943537  11.807484   3977749     263        7  ...
# 41  50.943537  11.807484   3977749     263        7  ...
# 42  20.407535  13.483354   3977749     311        7  ...
# 43  20.407535  13.483354   3977749     311        7  ...
# 44  45.106872  10.505330   3977749     192        7  ...
# 45  45.106872  10.505330   3977749     192        7  ...
# 46  43.015809  18.791562   3977749     145        7  ...
# 47  43.015809  18.791562   3977749     145        7  ...
# 48  51.594876  10.371822   3977749      46        7  ...
# 49  51.594876  10.371822   3977749      46        7  ...
# 50  55.272168  12.386634   3977749    4423        7  ...
# 51  55.272168  12.386634   3977749    4423        7  ...
#
#                                              filename  \
# 0   red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 1   red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 2   red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 3   red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 4   red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 5   red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 6   red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 7   red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 8   red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 9   red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 10  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 11  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 12  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 13  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 14  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 15  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 16  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 17  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 18  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 19  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 20  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 21  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 22  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 23  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 24  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 25  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 26  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 27  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 28  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 29  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 30  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 31  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 32  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 33  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 34  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 35  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 36  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 37  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 38  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 39  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 40  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 41  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 42  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 43  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 44  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 45  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 46  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 47  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 48  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 49  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 50  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
# 51  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
#
#                                           archivepath  aperture_x  aperture_y  \
# 0   /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   625.73650  3682.58000
# 1   /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   625.73650  3682.58000
# 2   /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   481.61743  3275.99830
# 3   /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   481.61743  3275.99830
# 4   /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   235.87636  3263.78470
# 5   /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   235.87636  3263.78470
# 6   /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   592.94240  2777.91800
# 7   /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   592.94240  2777.91800
# 8   /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   488.62170  2234.37770
# 9   /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   488.62170  2234.37770
# 10  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   316.43088  2137.75980
# 11  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   316.43088  2137.75980
# 12  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   230.81158  1353.56470
# 13  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   230.81158  1353.56470
# 14  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   300.19376   879.79865
# 15  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   300.19376   879.79865
# 16  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   208.93755   431.72452
# 17  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   208.93755   431.72452
# 18  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   309.11430  2147.42630
# 19  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   309.11430  2147.42630
# 20  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   403.64990  1569.98160
# 21  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   403.64990  1569.98160
# 22  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   231.28128   469.89496
# 23  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   231.28128   469.89496
# 24  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   578.75714  3574.65550
# 25  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   578.75714  3574.65550
# 26  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   211.72449  3582.44260
# 27  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   211.72449  3582.44260
# 28  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   433.33575  3484.83840
# 29  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   433.33575  3484.83840
# 30  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   519.14550  2980.07840
# 31  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   519.14550  2980.07840
# 32  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   448.55194  3036.78900
# 33  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   448.55194  3036.78900
# 34  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   665.73944  2974.72300
# 35  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   665.73944  2974.72300
# 36  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   631.34160  2853.99150
# 37  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   631.34160  2853.99150
# 38  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   471.70557  2103.23360
# 39  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   471.70557  2103.23360
# 40  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   505.84442  2092.00370
# 41  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   505.84442  2092.00370
# 42  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   646.60860  3323.77150
# 43  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   646.60860  3323.77150
# 44  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   393.91080  3478.21170
# 45  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   393.91080  3478.21170
# 46  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   351.90573  2752.59740
# 47  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   351.90573  2752.59740
# 48  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   238.59521  1340.23690
# 49  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   238.59521  1340.23690
# 50  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   171.38150   270.78440
# 51  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...   171.38150   270.78440
#
#     aperture_theta  aperture_a aperture_b  \
# 0          47.0722    1.522199   0.842106
# 1          47.0722    1.522199   0.842106
# 2          66.7464    1.568114   1.292097
# 3          66.7464    1.568114   1.292097
# 4         -87.9988    1.263849   0.899413
# 5         -87.9988    1.263849   0.899413
# 6          45.1010    1.086408   0.959926
# 7          45.1010    1.086408   0.959926
# 8           0.8428    1.221369   1.147326
# 9           0.8428    1.221369   1.147326
# 10         32.8868    0.887730   0.794744
# 11         32.8868    0.887730   0.794744
# 12         60.9500    1.112308   1.001934
# 13         60.9500    1.112308   1.001934
# 14         31.6078    0.924430   0.795220
# 15         31.6078    0.924430   0.795220
# 16        -15.3033    1.048968   0.806856
# 17        -15.3033    1.048968   0.806856
# 18         -3.9907    0.670311   0.670311
# 19         -3.9907    0.670311   0.670311
# 20         84.9683    2.078778   0.775502
# 21         84.9683    2.078778   0.775502
# 22        -20.0213    1.420110   1.111302
# 23        -20.0213    1.420110   1.111302
# 24         -6.6102    0.670311   0.670311
# 25         -6.6102    0.670311   0.670311
# 26         22.5005    1.476752   1.424456
# 27         22.5005    1.476752   1.424456
# 28        -11.1097    0.670311   0.670311
# 29        -11.1097    0.670311   0.670311
# 30        -15.4647    1.515534   1.357068
# 31        -15.4647    1.515534   1.357068
# 32         18.5651    0.670311   0.670311
# 33         18.5651    0.670311   0.670311
# 34         43.4214    1.377087   0.880175
# 35         43.4214    1.377087   0.880175
# 36        -74.7064    0.733652   0.698836
# 37        -74.7064    0.733652   0.698836
# 38         -4.8696    0.670311   0.670311
# 39         -4.8696    0.670311   0.670311
# 40        -82.9197    1.144746   0.979809
# 41        -82.9197    1.144746   0.979809
# 42        -52.9264    0.670311   0.670311
# 43        -52.9264    0.670311   0.670311
# 44         67.8305    1.018812   0.974788
# 45         67.8305    1.018812   0.974788
# 46        -72.0110    1.062542   0.891341
# 47        -72.0110    1.062542   0.891341
# 48        -16.6282    1.344819   0.844703
# 49        -16.6282    1.344819   0.844703
# 50        -85.8242    1.163699   1.045749
# 51        -85.8242    1.163699   1.045749
#
#                                                  path  flux_ca_error  \
# 0   /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       6.490427
# 1   /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       6.327577
# 2   /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       9.458920
# 3   /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       9.208642
# 4   /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       6.300242
# 5   /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       6.135968
# 6   /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       5.794663
# 7   /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       5.636511
# 8   /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       6.950058
# 9   /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       6.768906
# 10  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       5.007713
# 11  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       4.871241
# 12  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       6.440128
# 13  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       6.266433
# 14  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       5.378286
# 15  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       5.234012
# 16  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       6.019461
# 17  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       5.864302
# 18  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       4.218103
# 19  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       4.110683
# 20  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       7.649949
# 21  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       7.438971
# 22  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       8.012985
# 23  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       7.802657
# 24  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       4.005744
# 25  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       3.901889
# 26  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       8.318172
# 27  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       8.108526
# 28  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       4.129116
# 29  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       4.020275
# 30  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       8.210437
# 31  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       7.991380
# 32  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       4.415973
# 33  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       4.327753
# 34  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       6.432218
# 35  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       6.257396
# 36  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       4.318899
# 37  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       4.208331
# 38  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       4.672802
# 39  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       4.589283
# 40  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       6.275788
# 41  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       6.104371
# 42  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       3.991515
# 43  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       3.888807
# 44  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       5.806315
# 45  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       5.646950
# 46  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       5.711603
# 47  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       5.563639
# 48  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       6.557961
# 49  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       6.377634
# 50  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       7.185825
# 51  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       6.988606
#
#        flux_ca
# 0   112.816460
# 1   109.649527
# 2   120.700870
# 3   117.312610
# 4    89.547212
# 5    87.033484
# 6    51.217040
# 7    49.779298
# 8    99.019448
# 9    96.239819
# 10   45.402937
# 11   44.128407
# 12   67.804049
# 13   65.900684
# 14   60.284669
# 15   58.592385
# 16   91.753621
# 17   89.177955
# 18   68.520344
# 19   66.596872
# 20   53.563142
# 21   52.059542
# 22  108.784340
# 23  105.730595
# 24   59.016681
# 25   57.359992
# 26  141.815482
# 27  137.834502
# 28   54.314117
# 29   52.789435
# 30   97.272791
# 31   94.542193
# 32  126.785751
# 33  123.226679
# 34   60.911103
# 35   59.201234
# 36   68.314227
# 37   66.396541
# 38  150.690582
# 39  146.460464
# 40   54.694168
# 41   53.158818
# 42   61.435306
# 43   59.710722
# 44   45.881655
# 45   44.593686
# 46   84.555736
# 47   82.182126
# 48   49.646684
# 49   48.253025
# 50   56.843769
# 51   55.248077
#
# [52 rows x 26 columns]

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   annulus_mean     52 non-null     float64
#  1   annulus_median   52 non-null     float64
#  2   annulus_std      52 non-null     float64
#  3   annulus_samples  52 non-null     float64
#  4   raw_flux         52 non-null     float64
#  5   area             52 non-null     float64
#  6   flux_obs         52 non-null     float64
#  7   image_id         52 non-null     int64
#  8   ref_id           52 non-null     int64
#  9   ccd_num          52 non-null     int64
#  10  filter           52 non-null     object
#  11  I_auto           52 non-null     float64
#  12  zp               52 non-null     float64
#  13  zp_error         52 non-null     float64
#  14  flux             52 non-null     float64
#  15  flux_error       52 non-null     float64
#  16  filename         52 non-null     object
#  17  archivepath      52 non-null     object
#  18  aperture_x       52 non-null     float64
#  19  aperture_y       52 non-null     float64
#  20  aperture_theta   52 non-null     float64
#  21  aperture_a       52 non-null     float64
#  22  aperture_b       52 non-null     float64
#  23  path             52 non-null     object
#  24  flux_ca_error    52 non-null     float64
#  25  flux_ca          52 non-null     float64
# dtypes: float64(19), int64(3), object(4)
# memory usage: 10.7+ KB

# %%
num = 1
row = filtered_df.iloc[[num]]
row
# Out:
#    annulus_mean  annulus_median  annulus_std  annulus_samples    raw_flux  \
# 1      1.702658        1.700675     0.177788           8229.0  124.010657
#
#         area  flux_obs  image_id  ref_id  ccd_num  ...  \
# 1  58.220573  24.99637   3977749      30        7  ...
#
#                                             filename  \
# 1  red_NightlyR11.paucam.21763.1003.0149.FT_NB695...
#
#                                          archivepath  aperture_x  aperture_y  \
# 1  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...    625.7365     3682.58
#
#    aperture_theta  aperture_a aperture_b  \
# 1         47.0722    1.522199   0.842106
#
#                                                 path  flux_ca_error  \
# 1  /pnfs/pic.es/data/vo.paus.pic.es/paus/disk/arc...       6.327577
#
#       flux_ca
# 1  109.649527
#
# [1 rows x 26 columns]

# %%
path = filtered_df['path'][num]
image = fits.getdata(path)
mask_cutout = fits.getdata(path.replace('.fits', '.mask.fits'))

cutout_size = 48
aperture_x = cutout_size + row['aperture_x'].item() - math.floor(row['aperture_x'].item())
aperture_y = cutout_size + row['aperture_y'].item() - math.floor(row['aperture_y'].item())

stamp_image = creat_stamps(image, row)
mask_cutout = creat_stamps(mask_cutout, row)

# %%
#with my method
raw_flux, area = flux_elliptical_jiefeng(stamp_image, mask_cutout, aperture_x, aperture_y,
                                   row['aperture_theta'].item(),row['aperture_a'].item(),row['aperture_b'].item())
background = background_annulus_jiefeng(stamp_image, mask_cutout, aperture_x, aperture_y)

#with photutils
S_flux = flux_elliptical(stamp_image, mask_cutout, aperture_x, aperture_y,
                row['aperture_theta'].item(),row['aperture_a'].item(),row['aperture_b'].item())
S_bkg = background_annulus(stamp_image, mask_cutout, aperture_x, aperture_y)
# Out:
# (96, 96)

# %%
#compare the area I calculated with the apertures and the one from PAUS dataset
print('area')
print(area)
print(S_flux['area'])

print('bkg median flux')
print(background)
print(S_bkg['annulus_median'])

print('raw flux')
print(row['raw_flux'].item())
print(S_flux['raw_flux'].item())
print(raw_flux)

print('gal flux')
print(raw_flux - area * background)#my method
print(S_flux['raw_flux'] - S_flux['area'] * S_bkg['annulus_median'])#photutils
print(row['raw_flux'].item() - row['area'].item() * row['annulus_median'].item())#nayo
print(row['flux_obs'].item())

#It seems that the method works! Directly calculating the flux instead of using the photutils
# Out:
# area
# 58.22057311135204
# 58.22057311135204
# bkg median flux
# 1.7006752
# 1.7006752490997314
# raw flux
# 124.01065741448005
# 124.01065741448005
# 124.01065741448004
# gal flux
# 24.996369735602286
# 24.9963697356023
# 24.9963697356023
# 24.9963697356023

# %%
gal_flux = flux_elliptical_jiefeng(stamp_image, mask_cutout, aperture_x, aperture_y,
                                   row['aperture_theta'].item(),row['aperture_a'].item(),row['aperture_b'].item())
print(gal_flux)
# Out:
# (124.01065741448004, 58.22057311135204)

# %%
#use the propagation of the gradient
